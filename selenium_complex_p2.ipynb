# %%
from selenium import webdriver

# %%
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get('https://www.scrapethissite.com/pages/')

# %%
driver.get("https://www.scrapethissite.com/pages/ajax-javascript/")

# %%
from selenium.webdriver.common.by import By 

link_btn = driver.find_element(By.LINK_TEXT, '2010')
link_btn.click()

# %%
table_data = driver.find_element(By.CLASS_NAME, 'table')
table_data.tag_name
# Out:
# 'table'

# %%
from bs4 import BeautifulSoup
import pandas as pd

page_data = BeautifulSoup(driver.page_source)
movie_data = page_data.html.table
print(type(movie_data))
movie_data
# Out:
# <class 'bs4.element.Tag'>
# <table class="table" style="display: table;">
# <thead>
# <tr>
# <th>Title</th>
# <th>Nominations</th>
# <th>Awards</th>
# <th>Best Picture</th>
# </tr>
# </thead>
# <tbody id="table-body"><tr class="film"><td class="film-title">The King's Speech</td><td class="film-nominations">12</td><td class="film-awards">4</td><td class="film-best-picture"><i class="glyphicon glyphicon-flag"></i></td></tr><tr class="film"><td class="film-title">Inception</td><td class="film-nominations">8</td><td class="film-awards">4</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">The Social Network</td><td class="film-nominations">8</td><td class="film-awards">3</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">The Fighter</td><td class="film-nominations">7</td><td class="film-awards">2</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">Toy Story 3</td><td class="film-nominations">5</td><td class="film-awards">2</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">Alice in Wonderland</td><td class="film-nominations">3</td><td class="film-awards">2</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">Black Swan</td><td class="film-nominations">5</td><td class="film-awards">1</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">In a Better World</td><td class="film-nominations">1</td><td class="film-awards">1</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">The Lost Thing</td><td class="film-nominations">1</td><td class="film-awards">1</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">God of Love</td><td class="film-nominations">1</td><td class="film-awards">1</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">The Wolfman</td><td class="film-nominations">1</td><td class="film-awards">1</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">Strangers No More</td><td class="film-nominations">1</td><td class="film-awards">1</td><td class="film-best-picture"></td></tr><tr class="film"><td class="film-title">Inside Job</td><td class="film-nominations">1</td><td class="film-awards">1</td><td class="film-best-picture"></td></tr></tbody>
# </table>

# %%
df = pd.read_html(str(movie_data),header = 0)
df[0]
# Out:
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3642919071.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data),header = 0)
#                   Title  Nominations  Awards  Best Picture
# 0     The King's Speech           12       4           NaN
# 1             Inception            8       4           NaN
# 2    The Social Network            8       3           NaN
# 3           The Fighter            7       2           NaN
# 4           Toy Story 3            5       2           NaN
# 5   Alice in Wonderland            3       2           NaN
# 6            Black Swan            5       1           NaN
# 7     In a Better World            1       1           NaN
# 8        The Lost Thing            1       1           NaN
# 9           God of Love            1       1           NaN
# 10          The Wolfman            1       1           NaN
# 11    Strangers No More            1       1           NaN
# 12           Inside Job            1       1           NaN

# %%
from bs4 import BeautifulSoup
import pandas as pd

driver.get('https://www.scrapethissite.com/pages/ajax-javascript/')

year = 2015

link_btn = driver.find_element(By.LINK_TEXT, str(year))
link_btn.click()


# https://stackoverflow.com/questions/51336849/selenium-implicit-and-explicit-waits-not-working-has-no-effect
# wont work perfect reason above
# driver.implicitly_wait(5)

import time 
time.sleep(3)

page_data = BeautifulSoup(driver.page_source)
movie_data = page_data.table
print(type(movie_data))
movie_data
df = pd.read_html(str(movie_data), header = 0)
df[0]
# Out:
# <class 'bs4.element.Tag'>
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3514270634.py:23: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header = 0)
#                                             Title  Nominations  Awards  \
# 0                                       Spotlight            6       2
# 1                              Mad Max: Fury Road           10       6
# 2                                    The Revenant           12       3
# 3                                 Bridge of Spies            6       1
# 4                                   The Big Short            5       1
# 5                                 The Danish Girl            4       1
# 6                                            Room            4       1
# 7                                      Ex Machina            2       1
# 8                               The Hateful Eight            2       1
# 9                                      Inside Out            2       1
# 10                                            Amy            1       1
# 11                                     Bear Story            1       1
# 12  A Girl in the River: The Price of Forgiveness            1       1
# 13                                    Son of Saul            1       1
# 14                                        Spectre            1       1
# 15                                      Stutterer            1       1
#
#     Best Picture
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN

# %%
from bs4 import BeautifulSoup
import pandas as pd
import time 

driver.get('https://www.scrapethissite.com/pages/ajax-javascript/')

result_list = []

for year in range (2012, 2100):
    link_btn = driver.find_element(By.LINK_TEXT, str(year))
    link_btn.click()

    time.sleep(3)

    page_data = BeautifulSoup(driver.page_source)
    movie_data = page_data.table
    df = pd.read_html(str(movie_data), header = 0)
    result_list.append(df[0])

result_list
# Out:
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3461088678.py:17: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header = 0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3461088678.py:17: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header = 0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3461088678.py:17: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header = 0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3461088678.py:17: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header = 0)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[12], line 10
#       7 result_list = []
#       9 for year in range (2012, 2100):
# ---> 10     link_btn = driver.find_element(By.LINK_TEXT, str(year))
#      11     link_btn.click()
#      13     time.sleep(3)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"2016"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x00000001026c6a80 chromedriver + 4385408
# 1   chromedriver                        0x00000001026bf38c chromedriver + 4354956
# 2   chromedriver                        0x00000001022dcb0c chromedriver + 281356
# 3   chromedriver                        0x000000010231f2f8 chromedriver + 553720
# 4   chromedriver                        0x0000000102357d24 chromedriver + 785700
# 5   chromedriver                        0x0000000102313eec chromedriver + 507628
# 6   chromedriver                        0x00000001023148c4 chromedriver + 510148
# 7   chromedriver                        0x000000010268e43c chromedriver + 4154428
# 8   chromedriver                        0x0000000102692ea0 chromedriver + 4173472
# 9   chromedriver                        0x0000000102673ff8 chromedriver + 4046840
# 10  chromedriver                        0x000000010269378c chromedriver + 4175756
# 11  chromedriver                        0x0000000102666fb8 chromedriver + 3993528
# 12  chromedriver                        0x00000001026b121c chromedriver + 4297244
# 13  chromedriver                        0x00000001026b1398 chromedriver + 4297624
# 14  chromedriver                        0x00000001026bef84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000019ddf6f94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000019ddf1d34 thread_start + 8

# %%
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import time

driver.get("https://www.scrapethissite.com/pages/ajax-javascript/")
result_list = []
year = 2010

while True:
    try:
        link_btn = driver.find_element(By.LINK_TEXT, str(year))
        year += 1
        link_btn.click()
        
        time.sleep(3)
        
        page_data = BeautifulSoup(driver.page_source)
        movie_data = page_data.table
        df = pd.read_html(str(movie_data), header=0)
        result_list.append(df[0])
        
    except NoSuchElementException:
        break
        
result_list
# Out:
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3954741977.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header=0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3954741977.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header=0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3954741977.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header=0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3954741977.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header=0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3954741977.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header=0)
# /var/folders/50/1jxnmv8527s4kzh8dm8ky6mh0000gn/T/ipykernel_8195/3954741977.py:20: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(movie_data), header=0)
# [                  Title  Nominations  Awards  Best Picture
#  0     The King's Speech           12       4           NaN
#  1             Inception            8       4           NaN
#  2    The Social Network            8       3           NaN
#  3           The Fighter            7       2           NaN
#  4           Toy Story 3            5       2           NaN
#  5   Alice in Wonderland            3       2           NaN
#  6            Black Swan            5       1           NaN
#  7     In a Better World            1       1           NaN
#  8        The Lost Thing            1       1           NaN
#  9           God of Love            1       1           NaN
#  10          The Wolfman            1       1           NaN
#  11    Strangers No More            1       1           NaN
#  12           Inside Job            1       1           NaN,
#                                                  Title  Nominations  Awards  \
#  0                                          The Artist           10       5
#  1                                                Hugo           11       5
#  2                                       The Iron Lady            2       2
#  3                                     The Descendants            5       1
#  4                     The Girl with the Dragon Tattoo            5       1
#  5                                   Midnight in Paris            4       1
#  6                                            The Help            4       1
#  7                                        A Separation            2       1
#  8   The Fantastic Flying Books of Mr. Morris Lessmore            1       1
#  9                                           The Shore            1       1
#  10                                         Undefeated            1       1
#  11                                        The Muppets            1       1
#  12                                        Saving Face            1       1
#  13                                          Beginners            1       1
#  14                                              Rango            1       1
#
#      Best Picture
#  0            NaN
#  1            NaN
#  2            NaN
#  3            NaN
#  4            NaN
#  5            NaN
#  6            NaN
#  7            NaN
#  8            NaN
#  9            NaN
#  10           NaN
#  11           NaN
#  12           NaN
#  13           NaN
#  14           NaN  ,
#                        Title  Nominations  Awards  Best Picture
#  0                      Argo            7       3           NaN
#  1                Life of Pi           11       4           NaN
#  2            Les Misérables            8       3           NaN
#  3                   Lincoln           12       2           NaN
#  4          Django Unchained            5       2           NaN
#  5                   Skyfall            5       2           NaN
#  6   Silver Linings Playbook            8       1           NaN
#  7          Zero Dark Thirty            5       1           NaN
#  8                     Amour            5       1           NaN
#  9             Anna Karenina            4       1           NaN
#  10                 Paperman            1       1           NaN
#  11                    Brave            1       1           NaN
#  12  Searching for Sugar Man            1       1           NaN
#  13                 Inocente            1       1           NaN
#  14                   Curfew            1       1           NaN,
#                                          Title  Nominations  Awards  \
#  0                            12 Years a Slave            9       3
#  1                                     Gravity           10       7
#  2                          Dallas Buyers Club            6       3
#  3                                      Frozen            2       2
#  4                            The Great Gatsby            2       2
#  5                                         Her            5       1
#  6                                Blue Jasmine            3       1
#  7                                   Mr Hublot            1       1
#  8   The Lady in Number 6: Music Saved My Life            1       1
#  9                                      Helium            1       1
#  10                           The Great Beauty            1       1
#  11                       20 Feet from Stardom            1       1
#
#      Best Picture
#  0            NaN
#  1            NaN
#  2            NaN
#  3            NaN
#  4            NaN
#  5            NaN
#  6            NaN
#  7            NaN
#  8            NaN
#  9            NaN
#  10           NaN
#  11           NaN  ,
#                                 Title  Nominations  Awards  Best Picture
#  0                            Birdman            9       4           NaN
#  1           The Grand Budapest Hotel            9       4           NaN
#  2                           Whiplash            5       3           NaN
#  3                 The Imitation Game            8       1           NaN
#  4                    American Sniper            6       1           NaN
#  5                            Boyhood            6       1           NaN
#  6                       Interstellar            5       1           NaN
#  7           The Theory of Everything            5       1           NaN
#  8                                Ida            2       1           NaN
#  9                              Selma            2       1           NaN
#  10                       Citizenfour            1       1           NaN
#  11                        Big Hero 6            1       1           NaN
#  12  Crisis Hotline: Veterans Press 1            1       1           NaN
#  13                    The Phone Call            1       1           NaN
#  14                       Still Alice            1       1           NaN
#  15                             Feast            1       1           NaN,
#                                              Title  Nominations  Awards  \
#  0                                       Spotlight            6       2
#  1                              Mad Max: Fury Road           10       6
#  2                                    The Revenant           12       3
#  3                                 Bridge of Spies            6       1
#  4                                   The Big Short            5       1
#  5                                 The Danish Girl            4       1
#  6                                            Room            4       1
#  7                                      Ex Machina            2       1
#  8                               The Hateful Eight            2       1
#  9                                      Inside Out            2       1
#  10                                            Amy            1       1
#  11                                     Bear Story            1       1
#  12  A Girl in the River: The Price of Forgiveness            1       1
#  13                                    Son of Saul            1       1
#  14                                        Spectre            1       1
#  15                                      Stutterer            1       1
#
#      Best Picture
#  0            NaN
#  1            NaN
#  2            NaN
#  3            NaN
#  4            NaN
#  5            NaN
#  6            NaN
#  7            NaN
#  8            NaN
#  9            NaN
#  10           NaN
#  11           NaN
#  12           NaN
#  13           NaN
#  14           NaN
#  15           NaN  ]

# %%
print(len(result_list))
# Out:
# 6

# %%
# https://stackoverflow.com/questions/51336849/selenium-implicit-and-explicit-waits-not-working-has-no-effect
# wont work perfect reason above
# driver.implicitly_wait(5)
# from selenium.webdriver.support import expected_conditions as EC
# from selenium.webdriver.support.wait import WebDriverWait

# this will wait at least 10 seconds until url will contain "your_url"
# WebDriverWait(driver, 10).until(EC.url_contains(("your_url")))
